# %% [markdown]
# <a href="https://colab.research.google.com/github/Engenner/Angel-Quiguiri/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Predicción del Riesgo País de Ecuador con una Red Neuronal LSTM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Configuracion de graficos

# %%
sns.set_style("darkgrid")
sns.set_palette("viridis")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# Cargar y exploración de datos

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Ruta al archivo CSV en Drive
data_path = '/content/drive/MyDrive/Investigacion M_CV/riesgo-pas (1).csv'

# Cargar el dataset
try:
    df = pd.read_csv(data_path, parse_dates=['Período'], dayfirst=False)
    print(f"Dataset '{data_path}' cargado exitosamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{data_path}' no se encontró. Asegúrate de que la ruta sea correcta.")
except Exception as e:
    print(f"Ocurrió un error al cargar el archivo: {e}")
# Out:
# Dataset '/content/drive/MyDrive/Investigacion M_CV/riesgo-pas (1).csv' cargado exitosamente.

# %%
print("="*60)
print("Información del dataset")
print("="*60)
print(f"Dimensiones del dataset: {df.shape}")
print(f"Rango de fechas: {df['Período'].min()} a {df['Período'].max()}")
print(f"Número de días con datos: {df['Período'].nunique()}")
print("\nPrimeras 5 filas del dataset:")
print(df.head())
print("\nEstadísticas descriptivas:")
print(df['Riesgo País en Puntos Básicos'].describe())
# Out:
# ============================================================
# Información del dataset
# ============================================================
# Dimensiones del dataset: (7310, 2)
# Rango de fechas: 2004-07-29 00:00:00 a 2026-06-30 00:00:00
# Número de días con datos: 7310
#
# Primeras 5 filas del dataset:
#      Período  Riesgo País en Puntos Básicos
# 0 2004-07-29                            870
# 1 2004-07-30                            852
# 2 2004-07-31                            852
# 3 2004-08-01                            852
# 4 2004-08-02                            872
#
# Estadísticas descriptivas:
# count    7310.000000
# mean      971.104241
# std       708.453339
# min       289.000000
# 25%       631.000000
# 50%       774.000000
# 75%       979.000000
# max      6063.000000
# Name: Riesgo País en Puntos Básicos, dtype: float64

# %% [markdown]
# Procesamiento de datos

# %%
# Verificar valores nulos
if df.isnull().sum().sum() > 0:
    print(f"\nSe encontraron {df.isnull().sum().sum()} valores nulos. Se procederá a llenarlos.")
    df = df.fillna(method='ffill')  # Forward fill para series temporales

# Extraer la serie temporal
serie_temporal = df['Riesgo País en Puntos Básicos'].values.reshape(-1, 1)

# Normalización de los datos (escala 0-1)
scaler = MinMaxScaler(feature_range=(0, 1))
serie_normalizada = scaler.fit_transform(serie_temporal)

print("\n" + "="*60)
print("Preprocesamiento completado")
print("="*60)
print(f"Rango de datos originales: {serie_temporal.min():.0f} - {serie_temporal.max():.0f}")
print(f"Rango de datos normalizados: {serie_normalizada.min():.4f} - {serie_normalizada.max():.4f}")
# Out:
# ============================================================
# Preprocesamiento completado
# ============================================================
# Rango de datos originales: 289 - 6063
# Rango de datos normalizados: 0.0000 - 1.0000

# %% [markdown]
# Creación de secuencias para el modelo LSTM

# %%
def crear_secuencias(data, look_back=60):
    """
    Crea secuencias de datos para el modelo LSTM.

    Parámetros:
    - data: array con los datos normalizados.
    - look_back: número de pasos atrás para predecir el siguiente valor.

    Retorna:
    - X: características (secuencias de entrada).
    - y: etiquetas (valor a predecir).
    """
    X, y = [], []
    for i in range(look_back, len(data)):
        X.append(data[i-look_back:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# Definir el número de pasos de tiempo (ventana de observación)
LOOK_BACK = 60  # 60 días para predecir el siguiente

# Crear secuencias
X, y = crear_secuencias(serie_normalizada, LOOK_BACK)

# Redimensionar X para LSTM: [muestras, pasos_tiempo, características]
X = X.reshape(X.shape[0], X.shape[1], 1)

print("\n" + "="*60)
print("CREACIÓN DE SECUENCIAS")
print("="*60)
print(f"Forma de X: {X.shape}")
print(f"Forma de y: {y.shape}")
# Out:
# ============================================================
# CREACIÓN DE SECUENCIAS
# ============================================================
# Forma de X: (7250, 60, 1)
# Forma de y: (7250,)

# %% [markdown]
# División en conjuntos de entrenamiento y prueba

# %%
# Dividir los datos en entrenamiento (80%) y prueba (20%)
tamano_entrenamiento = int(len(X) * 0.8)
X_train, X_test = X[:tamano_entrenamiento], X[tamano_entrenamiento:]
y_train, y_test = y[:tamano_entrenamiento], y[tamano_entrenamiento:]

print("\n" + "="*60)
print("DIVISIÓN DE DATOS")
print("="*60)
print(f"Muestras de entrenamiento: {X_train.shape[0]}")
print(f"Muestras de prueba: {X_test.shape[0]}")
# Out:
# ============================================================
# DIVISIÓN DE DATOS
# ============================================================
# Muestras de entrenamiento: 5800
# Muestras de prueba: 1450

# %% [markdown]
# Construcción del modelo  LSTM

# %%
# Inicializar el modelo
modelo_lstm = Sequential()

# Capa LSTM 1
modelo_lstm.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
modelo_lstm.add(Dropout(0.2))

# Capa LSTM 2
modelo_lstm.add(LSTM(units=50, return_sequences=False))
modelo_lstm.add(Dropout(0.2))

# Capa densa de salida
modelo_lstm.add(Dense(units=1))

# Compilar el modelo
modelo_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Resumen del modelo
print("\n" + "="*60)
print("ARQUITECTURA DEL MODELO LSTM")
print("="*60)
modelo_lstm.summary()
# Out:
# ============================================================
# ARQUITECTURA DEL MODELO LSTM
# ============================================================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Entrenamiento del modelo

# %%
# Configurar early stopping para evitar sobreajuste
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Entrenar el modelo
print("\n" + "="*60)
print("ENTRENAMIENTO DEL MODELO")
print("="*60)
print("Iniciando entrenamiento...")
historia = modelo_lstm.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# ============================================================
# ENTRENAMIENTO DEL MODELO
# ============================================================
# Iniciando entrenamiento...
# Epoch 1/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 15s 65ms/step - loss: 0.0019 - val_loss: 5.4163e-04
# Epoch 2/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 8.7344e-04 - val_loss: 1.6321e-04
# Epoch 3/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - loss: 6.6994e-04 - val_loss: 1.6424e-04
# Epoch 4/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 18s 55ms/step - loss: 5.9479e-04 - val_loss: 1.5688e-04
# Epoch 5/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 5.3652e-04 - val_loss: 1.4215e-04
# Epoch 6/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 4.6578e-04 - val_loss: 1.6647e-04
# Epoch 7/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 4.8904e-04 - val_loss: 1.3842e-04
# Epoch 8/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - loss: 4.8251e-04 - val_loss: 1.3505e-04
# Epoch 9/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 5.2279e-04 - val_loss: 1.6427e-04
# Epoch 10/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 4.0986e-04 - val_loss: 9.4996e-05
# Epoch 11/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 67ms/step - loss: 3.8329e-04 - val_loss: 8.9763e-05
# Epoch 12/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 4.1669e-04 - val_loss: 9.7184e-05
# Epoch 13/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 4.1744e-04 - val_loss: 8.9838e-05
# Epoch 14/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 4.1316e-04 - val_loss: 1.0286e-04
# Epoch 15/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - loss: 3.7444e-04 - val_loss: 7.8483e-05
# Epoch 16/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 3.4690e-04 - val_loss: 1.0122e-04
# Epoch 17/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - loss: 3.6535e-04 - val_loss: 1.6677e-04
# Epoch 18/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - loss: 3.9711e-04 - val_loss: 1.3629e-04
# Epoch 19/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - loss: 3.9532e-04 - val_loss: 7.2228e-05
# Epoch 20/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - loss: 3.6497e-04 - val_loss: 1.8775e-04
# Epoch 21/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 3.1700e-04 - val_loss: 7.4911e-05
# Epoch 22/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 3.3379e-04 - val_loss: 6.3472e-05
# Epoch 23/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 3.1005e-04 - val_loss: 2.6801e-04
# Epoch 24/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 3.4413e-04 - val_loss: 8.4607e-05
# Epoch 25/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 3.2817e-04 - val_loss: 8.7172e-05
# Epoch 26/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.9174e-04 - val_loss: 6.2198e-05
# Epoch 27/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.9265e-04 - val_loss: 8.7558e-05
# Epoch 28/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 3.2385e-04 - val_loss: 7.8830e-05
# Epoch 29/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 3.1131e-04 - val_loss: 5.8802e-05
# Epoch 30/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - loss: 3.4142e-04 - val_loss: 8.5477e-05
# Epoch 31/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 3.5300e-04 - val_loss: 5.5983e-05
# Epoch 32/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 2.9237e-04 - val_loss: 8.6498e-05
# Epoch 33/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.1256e-04 - val_loss: 8.0482e-05
# Epoch 34/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - loss: 3.1144e-04 - val_loss: 5.6917e-05
# Epoch 35/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 3.2692e-04 - val_loss: 1.2142e-04
# Epoch 36/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 3.1344e-04 - val_loss: 9.2280e-05
# Epoch 37/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.3916e-04 - val_loss: 8.7459e-05
# Epoch 38/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.2678e-04 - val_loss: 8.7575e-05
# Epoch 39/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 67ms/step - loss: 3.2280e-04 - val_loss: 6.1105e-05
# Epoch 40/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.3837e-04 - val_loss: 6.9071e-05
# Epoch 41/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 3.2844e-04 - val_loss: 5.6391e-05
# Epoch 42/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 65ms/step - loss: 3.3012e-04 - val_loss: 9.0543e-05
# Epoch 43/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 3.4128e-04 - val_loss: 5.3697e-05
# Epoch 44/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - loss: 2.9982e-04 - val_loss: 7.5728e-05
# Epoch 45/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.9630e-04 - val_loss: 6.0965e-05
# Epoch 46/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.9879e-04 - val_loss: 5.0171e-05
# Epoch 47/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - loss: 2.7901e-04 - val_loss: 5.4976e-05
# Epoch 48/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 2.8097e-04 - val_loss: 5.2710e-05
# Epoch 49/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.1965e-04 - val_loss: 6.3670e-05
# Epoch 50/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.2780e-04 - val_loss: 9.4995e-05
# Epoch 51/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 67ms/step - loss: 3.3172e-04 - val_loss: 1.7156e-04
# Epoch 52/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 3.1012e-04 - val_loss: 6.3917e-05
# Epoch 53/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - loss: 2.9485e-04 - val_loss: 7.6459e-05
# Epoch 54/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - loss: 2.7191e-04 - val_loss: 9.6572e-05
# Epoch 55/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - loss: 3.3667e-04 - val_loss: 6.5486e-05
# Epoch 56/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 3.2012e-04 - val_loss: 4.7988e-05
# Epoch 57/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - loss: 2.8528e-04 - val_loss: 8.4791e-05
# Epoch 58/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 64ms/step - loss: 2.9649e-04 - val_loss: 7.3861e-05
# Epoch 59/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 2.5250e-04 - val_loss: 5.0241e-05
# Epoch 60/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.9625e-04 - val_loss: 6.6218e-05
# Epoch 61/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step - loss: 2.9499e-04 - val_loss: 5.5413e-05
# Epoch 62/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.7907e-04 - val_loss: 6.8879e-05
# Epoch 63/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - loss: 3.0560e-04 - val_loss: 6.1794e-05
# Epoch 64/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - loss: 2.9008e-04 - val_loss: 6.5170e-05
# Epoch 65/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.7267e-04 - val_loss: 6.1974e-05
# Epoch 66/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 3.2400e-04 - val_loss: 6.6294e-05
# Epoch 67/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.7150e-04 - val_loss: 1.4592e-04
# Epoch 68/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.9402e-04 - val_loss: 8.7319e-05
# Epoch 69/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - loss: 3.1084e-04 - val_loss: 6.8262e-05
# Epoch 70/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - loss: 3.2302e-04 - val_loss: 7.1464e-05
# Epoch 71/100
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - loss: 2.7131e-04 - val_loss: 1.7136e-04
